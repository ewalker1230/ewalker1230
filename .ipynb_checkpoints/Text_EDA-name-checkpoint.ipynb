# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB         # Naive Bayes
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import codecs

import time
from datetime import date
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
data = r'AB_Clean.csv'
pd.set_option('display.max_columns', 500)
AB_Clean = pd.read_csv(data)
AB_Clean.tail(1)
# Out:
#       Unnamed: 0 last_scraped                                   name  \
# 2828        3583   2016-09-07  Great Location; Train and Restaurants
#
#                                                 summary space  \
# 2828  My place is close to Taco Loco Mexican Grill, ...   NaN
#
#                                             description neighborhood_overview  \
# 2828  My place is close to Taco Loco Mexican Grill, ...                   NaN
#
#      transit access house_rules  host_since  \
# 2828     NaN    NaN         NaN  2016-05-27
#
#                                              host_about  \
# 2828  Hi, I am very friendly, helpful, positive and ...
#
#       host_total_listings_count neighbourhood zipcode     room_type  \
# 2828                          4    Somerville   02145  Private room
#
#       accommodates  bathrooms  beds  bed_type  \
# 2828             2        1.0   1.0  Real Bed
#
#                                               amenities   price  \
# 2828  {Kitchen,Gym,"Family/Kid Friendly",Washer,Drye...  $65.00
#
#       availability_90 calendar_last_scraped first_review last_review  \
# 2828                5            2016-09-06   2016-08-27  2016-09-04
#
#       calculated_host_listings_count  reviews_per_month  price_int  price_bed  \
# 2828                               1                2.0       65.0       65.0
#
#       Host_Age  RPM
# 2828       103    1

# %%
AB_Clean.dtypes
# Out:
# Unnamed: 0                          int64
# last_scraped                       object
# name                               object
# summary                            object
# space                              object
# description                        object
# neighborhood_overview              object
# transit                            object
# access                             object
# house_rules                        object
# host_since                         object
# host_about                         object
# host_total_listings_count           int64
# neighbourhood                      object
# zipcode                            object
# room_type                          object
# accommodates                        int64
# bathrooms                         float64
# beds                              float64
# bed_type                           object
# amenities                          object
# price                              object
# availability_90                     int64
# calendar_last_scraped              object
# first_review                       object
# last_review                        object
# calculated_host_listings_count      int64
# reviews_per_month                 float64
# price_int                         float64
# price_bed                         float64
# Host_Age                            int64
# RPM                                 int64
# dtype: object

# %%
AB_Clean_text=AB_Clean[['name','description','host_about']]
AB_Clean_text.head(3)
# Out:
#                                             name  \
# 0              Charming room in pet friendly apt
# 1               Mexican Folk Art Haven in Boston
# 2  Spacious Sunny Bedroom Suite in Historic Home
#
#                                          description  \
# 0  Charming and quiet room in a second floor 1910...
# 1  Come stay with a friendly, middle-aged guy in ...
# 2  Come experience the comforts of home away from...
#
#                                           host_about
# 0  I live in Boston and I like to travel and have...
# 1  I am a middle-aged, single male with a wide ra...
# 2  My husband and I live on the property.  He’s a...

# %%
# Append all reviews into one string
text_desc = " ".join(review for review in AB_Clean_text.name)

# %%
text_desc
# Out:
# 'Charming room in pet friendly apt Mexican Folk Art Haven in Boston Spacious Sunny Bedroom Suite in Historic Home Come Home to Boston Private Bedroom + Great Coffee New Lrg Studio apt 15 min to Boston "Tranquility" on "Top of the Hill" 6 miles away from downtown Boston! Perfect & Practical Boston Rental Cozy room in a well located house Room in Rozzie-Twin Bed-Full Bath Updated, spacious living in Rozzie 2 Bedroom Apartment in Boston Quiet  Beauty in Boston Cozy Room & Fresh Roasted Coffee Convient, Safe and Comfortable Roslindale Beauty next to Arboretum Private Room near Public Transport Cozy room in a charming villa. Arborside Guest Cottage Skyline View to Boston Spacious 3 bedroom cape cod style 4BD/3.5BA, Perfect for families! Private room in house  Surround yourself with custom art! Sunny bedroom with private bathroom Bright Room Near Roslindale Village Room for 2 in Rozzie - Full Bath Private room in spacious condo! Adorable  Apt. 20 min from Downtown Private Room near public transport Charming Gambrel on a sweet street Private 1 bedroom w/ kitchenette Charming 3 bedroom-15 min to Boston Charming new house-15 min to Boston "Room with a View"  from "Top of the Hill" Lovely & Gracious Victorian room Cozy, quiet room in Roslindale Private Room in Rozzie Queen room in a charming villa Charming sunlit house in Boston Guest Room in Cozy Home Sunny bedroom in large quiet house Cozy in Rozzie! Private Room in Single Family Home The Artist room in beautiful villa. PrivRoom+Bath In Roslindale/Boston 1bd Boston apt - Convenient & quiet Quiet Sunlit Attic Studio Private House in Roslindale/Boston/Arboretum Gorgeous Boston Loft Style Condo! Private room in peaceful space Loft bedroom, sleeps 2 Part of a Large Condo Jamaica Plain Beautiful and sunny condo  Sunlit room with private bath Bed, Bath and Beyond III in JP Private studio by subway w/parking Spacious room convenient to subway Cozy Room off Centre St, JP! Private floor in Jamaica Plain home Spacious room in secluded townhouse Charming Victorian near T Beautiful, Expansive Space in JP Cozy Room + Private Bath, JP Boston Beautiful, airy room in JP Cozy JP bedroom near Orange Line T Great Boston neighborhood Jamaica PLain Qn BR/Private Bath/Superhost/JP Ctr Mark P.Coleman JP Gem The Blue Room in JP Parking/Pvt Bath/Hip Neighborhood! Cozy den, private apt/kitchen/bath Sunny and quiet private room close to subway (JP) Room in beautiful JP home Convenient green Victorian Cozy room in boston neighborhood Peaceful room, garden oasis Lg sunny room w/private entrance Spacious 2 bedroom apartment (free parking) Beautiful bright corner unit!ioc Clean Apartment in Boston Stay in Boston\'s top neighborhood Bright room with queen sized bed Spacious home in Jamaica Plain 4 bedroom Victorian Condo unit Lovely bedroom/use of whole apt. A suburban feel in the city Stay in Boston\'s best neighborhood! Elegant studio,kitchn, soaking tub Priv apt w/2 Beds 1 bath close to Medical/Downtown Cozy bedroom near train, bus, parks Quiet & Sunny Room Near Subway Lovely one bedroom Apt Spacious Apartment in Jamaica Plain Pondside Paradise with Piano Convenient, Sunny 3b/2bth w/Parking Tranquil Treetop Loft Historic Carriage House, a peaceful city oasis Large, sunny, cozy home w/character Boston 2 bedroom top floor condo w/balcony! Charming 2BD Across from Arboretum Hidden Gem in Jamaica Plain, Boston JP Whole awesome apartment Private Room in Urban DIY House Cozy room in Jamaica Plain Sunny, Cozy and Convenient JP Home! Vintage Apt With 3 Large Bedrooms Large and Cozy Boston Bedroom Private Apartment! Sunny apartment in Boston hosts 6 One Private Bedroom in J.P. 3+ bedroom house - center of JP Luxury Apt near Restaurants&Pond&T Designers Haven: II - whole apt!!! Spacious 2BD w/ Balconies & Parking "The Sheridan" JP, Boston Fully Renovated Room in JP Restful space with morning light Private bedroom in heart of JP Welcome to cozy groundfloor 2rm apt Cozy Sunroom in Secluded Townhouse Twins in a peaceful room. ...

# %%
words = nltk.word_tokenize(text_desc)

# %%
words
# Out:
# ['Charming',
#  'room',
#  'in',
#  'pet',
#  'friendly',
#  'apt',
#  'Mexican',
#  'Folk',
#  'Art',
#  'Haven',
#  'in',
#  'Boston',
#  'Spacious',
#  'Sunny',
#  'Bedroom',
#  'Suite',
#  'in',
#  'Historic',
#  'Home',
#  'Come',
#  'Home',
#  'to',
#  'Boston',
#  'Private',
#  'Bedroom',
#  '+',
#  'Great',
#  'Coffee',
#  'New',
#  'Lrg',
#  'Studio',
#  'apt',
#  '15',
#  'min',
#  'to',
#  'Boston',
#  '``',
#  'Tranquility',
#  "''",
#  'on',
#  '``',
#  'Top',
#  'of',
#  'the',
#  'Hill',
#  "''",
#  '6',
#  'miles',
#  'away',
#  'from',
#  'downtown',
#  'Boston',
#  '!',
#  'Perfect',
#  '&',
#  'Practical',
#  'Boston',
#  'Rental',
#  'Cozy',
#  'room',
#  'in',
#  'a',
#  'well',
#  'located',
#  'house',
#  'Room',
#  'in',
#  'Rozzie-Twin',
#  'Bed-Full',
#  'Bath',
#  'Updated',
#  ',',
#  'spacious',
#  'living',
#  'in',
#  'Rozzie',
#  '2',
#  'Bedroom',
#  'Apartment',
#  'in',
#  'Boston',
#  'Quiet',
#  'Beauty',
#  'in',
#  'Boston',
#  'Cozy',
#  'Room',
#  '&',
#  'Fresh',
#  'Roasted',
#  'Coffee',
#  'Convient',
#  ',',
#  'Safe',
#  'and',
#  'Comfortable',
#  'Roslindale',
#  'Beauty',
#  'next',
#  'to',
#  'Arboretum',
#  'Private',
#  'Room',
#  'near',
#  'Public',
#  'Transport',
#  'Cozy',
#  'room',
#  'in',
#  'a',
#  'charming',
#  'villa',
#  '.',
#  'Arborside',
#  'Guest',
#  'Cottage',
#  'Skyline',
#  'View',
#  'to',
#  'Boston',
#  'Spacious',
#  '3',
#  'bedroom',
#  'cape',
#  'cod',
#  'style',
#  '4BD/3.5BA',
#  ',',
#  'Perfect',
#  'for',
#  'families',
#  '!',
#  'Private',
#  'room',
#  'in',
#  'house',
#  'Surround',
#  'yourself',
#  'with',
#  'custom',
#  'art',
#  '!',
#  'Sunny',
#  'bedroom',
#  'with',
#  'private',
#  'bathroom',
#  'Bright',
#  'Room',
#  'Near',
#  'Roslindale',
#  'Village',
#  'Room',
#  'for',
#  '2',
#  'in',
#  'Rozzie',
#  '-',
#  'Full',
#  'Bath',
#  'Private',
#  'room',
#  'in',
#  'spacious',
#  'condo',
#  '!',
#  'Adorable',
#  'Apt',
#  '.',
#  '20',
#  'min',
#  'from',
#  'Downtown',
#  'Private',
#  'Room',
#  'near',
#  'public',
#  'transport',
#  'Charming',
#  'Gambrel',
#  'on',
#  'a',
#  'sweet',
#  'street',
#  'Private',
#  '1',
#  'bedroom',
#  'w/',
#  'kitchenette',
#  'Charming',
#  '3',
#  'bedroom-15',
#  'min',
#  'to',
#  'Boston',
#  'Charming',
#  'new',
#  'house-15',
#  'min',
#  'to',
#  'Boston',
#  '``',
#  'Room',
#  'with',
#  'a',
#  'View',
#  "''",
#  'from',
#  '``',
#  'Top',
#  'of',
#  'the',
#  'Hill',
#  "''",
#  'Lovely',
#  '&',
#  'Gracious',
#  'Victorian',
#  'room',
#  'Cozy',
#  ',',
#  'quiet',
#  'room',
#  'in',
#  'Roslindale',
#  'Private',
#  'Room',
#  'in',
#  'Rozzie',
#  'Queen',
#  'room',
#  'in',
#  'a',
#  'charming',
#  'villa',
#  'Charming',
#  'sunlit',
#  'house',
#  'in',
#  'Boston',
#  'Guest',
#  'Room',
#  'in',
#  'Cozy',
#  'Home',
#  'Sunny',
#  'bedroom',
#  'in',
#  'large',
#  'quiet',
#  'house',
#  'Cozy',
#  'in',
#  'Rozzie',
#  '!',
#  'Private',
#  'Room',
#  'in',
#  'Single',
#  'Family',
#  'Home',
#  'The',
#  'Artist',
#  'room',
#  'in',
#  'beautiful',
#  'villa',
#  '.',
#  'PrivRoom+Bath',
#  'In',
#  'Roslindale/Boston',
#  '1bd',
#  'Boston',
#  'apt',
#  '-',
#  'Convenient',
#  '&',
#  'quiet',
#  'Quiet',
#  'Sunlit',
#  'Attic',
#  'Studio',
#  'Private',
#  'House',
#  'in',
#  'Roslindale/Boston/Arboretum',
#  'Gorgeous',
#  'Boston',
#  'Loft',
#  'Style',
#  'Condo',
#  '!',
#  'Private',
#  'room',
#  'in',
#  'peaceful',
#  'space',
#  'Loft',
#  'bedroom',
#  ',',
#  'sleeps',
#  '2',
#  'Part',
#  'of',
#  'a',
#  'Large',
#  'Condo',
#  'Jamaica',
#  'Plain',
#  'Beautiful',
#  'and',
#  'sunny',
#  'condo',
#  'Sunlit',
#  'room',
#  'with',
#  'private',
#  'bath',
#  'Bed',
#  ',',
#  'Bath',
#  'and',
#  'Beyond',
#  'III',
#  'in',
#  'JP',
#  'Private',
#  'studio',
#  'by',
#  'subway',
#  'w/parking',
#  'Spacious',
#  'room',
#  'convenient',
#  'to',
#  'subway',
#  'Cozy',
#  'Room',
#  'off',
#  'Centre',
#  'St',
#  ',',
#  'JP',
#  '!',
#  'Private',
#  'floor',
#  'in',
#  'Jamaica',
#  'Plain',
#  'home',
#  'Spacious',
#  'room',
#  'in',
#  'secluded',
#  'townhouse',
#  'Charming',
#  'Victorian',
#  'near',
#  'T',
#  'Beautiful',
#  ',',
#  'Expansive',
#  'Space',
#  'in',
#  'JP',
#  'Cozy',
#  'Room',
#  '+',
#  'Private',
#  'Bath',
#  ',',
#  'JP',
#  'Boston',
#  'Beautiful',
#  ',',
#  'airy',
#  'room',
#  'in',
#  'JP',
#  'Cozy',
#  'JP',
#  'bedroom',
#  'near',
#  'Orange',
#  'Line',
#  'T',
#  'Great',
#  'Boston',
#  'neighborhood',
#  'Jamaica',
#  'PLain',
#  'Qn',
#  'BR/Private',
#  'Bath/Superhost/JP',
#  'Ctr',
#  'Mark',
#  'P.Coleman',
#  'JP',
#  'Gem',
#  'The',
#  'Blue',
#  'Room',
#  'in',
#  'JP',
#  'Parking/Pvt',
#  'Bath/Hip',
#  'Neighborhood',
#  '!',
#  'Cozy',
#  'den',
#  ',',
#  'private',
#  'apt/kitchen/bath',
#  'Sunny',
#  'and',
#  'quiet',
#  'private',
#  'room',
#  'close',
#  'to',
#  'subway',
#  '(',
#  'JP',
#  ')',
#  'Room',
#  'in',
#  'beautiful',
#  'JP',
#  'home',
#  'Convenient',
#  'green',
#  'Victorian',
#  'Cozy',
#  'room',
#  'in',
#  'boston',
#  'neighborhood',
#  'Peaceful',
#  'room',
#  ',',
#  'garden',
#  'oasis',
#  'Lg',
#  'sunny',
#  'room',
#  'w/private',
#  'entrance',
#  'Spacious',
#  '2',
#  'bedroom',
#  'apartment',
#  '(',
#  'free',
#  'parking',
#  ')',
#  'Beautiful',
#  'bright',
#  'corner',
#  'unit',
#  '!',
#  'ioc',
#  'Clean',
#  'Apartment',
#  'in',
#  'Boston',
#  'Stay',
#  'in',
#  'Boston',
#  "'s",
#  'top',
#  'neighborhood',
#  'Bright',
#  'room',
#  'with',
#  'queen',
#  'sized',
#  'bed',
#  'Spacious',
#  'home',
#  'in',
#  'Jamaica',
#  'Plain',
#  '4',
#  'bedroom',
#  'Victorian',
#  'Condo',
#  'unit',
#  'Lovely',
#  'bedroom/use',
#  'of',
#  'whole',
#  'apt',
#  '.',
#  'A',
#  'suburban',
#  'feel',
#  'in',
#  'the',
#  'city',
#  'Stay',
#  'in',
#  'Boston',
#  "'s",
#  'best',
#  'neighborhood',
#  '!',
#  'Elegant',
#  'studio',
#  ',',
#  'kitchn',
#  ',',
#  'soaking',
#  'tub',
#  'Priv',
#  'apt',
#  'w/2',
#  'Beds',
#  '1',
#  'bath',
#  'close',
#  'to',
#  'Medical/Downtown',
#  'Cozy',
#  'bedroom',
#  'near',
#  'train',
#  ',',
#  'bus',
#  ',',
#  'parks',
#  'Quiet',
#  '&',
#  'Sunny',
#  'Room',
#  'Near',
#  'Subway',
#  'Lovely',
#  'one',
#  'bedroom',
#  'Apt',
#  'Spacious',
#  'Apartment',
#  'in',
#  'Jamaica',
#  'Plain',
#  'Pondside',
#  'Paradise',
#  'with',
#  'Piano',
#  'Convenient',
#  ',',
#  'Sunny',
#  '3b/2bth',
#  'w/Parking',
#  'Tranquil',
#  'Treetop',
#  'Loft',
#  'Historic',
#  'Carriage',
#  'House',
#  ',',
#  'a',
#  'peaceful',
#  'city',
#  'oasis',
#  'Large',
#  ',',
#  'sunny',
#  ',',
#  'cozy',
#  'home',
#  'w/character',
#  'Boston',
#  '2',
#  'bedroom',
#  'top',
#  'floor',
#  'condo',
#  'w/balcony',
#  '!',
#  'Charming',
#  '2BD',
#  'Across',
#  'from',
#  'Arboretum',
#  'Hidden',
#  'Gem',
#  'in',
#  'Jamaica',
#  'Plain',
#  ',',
#  'Boston',
#  'JP',
#  'Whole',
#  'awesome',
#  'apartment',
#  'Private',
#  'Room',
#  'in',
#  'Urban',
#  'DIY',
#  'House',
#  'Cozy',
#  'room',
#  'in',
#  'Jamaica',
#  'Plain',
#  'Sunny',
#  ',',
#  'Cozy',
#  'and',
#  'Convenient',
#  'JP',
#  'Home',
#  '!',
#  'Vintage',
#  'Apt',
#  'With',
#  '3',
#  'Large',
#  'Bedrooms',
#  'Large',
#  'and',
#  'Cozy',
#  'Boston',
#  'Bedroom',
#  'Private',
#  'Apartment',
#  '!',
#  'Sunny',
#  'apartment',
#  'in',
#  'Boston',
#  'hosts',
#  '6',
#  'One',
#  'Private',
#  'Bedroom',
#  'in',
#  'J.P.',
#  '3+',
#  'bedroom',
#  'house',
#  '-',
#  'center',
#  'of',
#  'JP',
#  'Luxury',
#  'Apt',
#  'near',
#  'Restaurants',
#  '&',
#  'Pond',
#  '&',
#  'T',
#  'Designers',
#  'Haven',
#  ':',
#  'II',
#  '-',
#  'whole',
#  'apt',
#  '!',
#  '!',
#  '!',
#  'Spacious',
#  '2BD',
#  'w/',
#  'Balconies',
#  '&',
#  'Parking',
#  '``',
#  'The',
#  'Sheridan',
#  "''",
#  'JP',
#  ',',
#  'Boston',
#  'Fully',
#  'Renovated',
#  'Room',
#  'in',
#  'JP',
#  'Restful',
#  'space',
#  'with',
#  'morning',
#  'light',
#  'Private',
#  'bedroom',
#  'in',
#  'heart',
#  'of',
#  'JP',
#  'Welcome',
#  'to',
#  'cozy',
#  'groundfloor',
#  '2rm',
#  'apt',
#  'Cozy',
#  'Sunroom',
#  'in',
#  'Secluded',
#  'Townhouse',
#  'Twins',
#  'in',
#  'a',
#  'peaceful',
#  'room',
#  '.',
#  'Room',
#  'in',
#  'the',
#  'heart',
#  'of',
#  'JP',
#  'Terrestrial',
#  'Paradise',
#  'of',
#  'Eternal',
#  'Love',
#  'Private',
#  'studio',
#  'w/',
#  'private',
#  'entrance',
#  '2BD',
#  'Pond-side',
#  'condo',
#  'in',
#  'JP',
#  'Quiet',
#  ',',
#  'Private',
#  'Room',
#  'with',
#  'Comfy',
#  'Bed',
#  'Private',
#  'Studio-',
#  'Minutes',
#  'from',
#  'T',
#  '!',
#  'Treetop',
#  'Haven',
#  'in',
#  'the',
#  'City',
#  'Funky',
#  'Alcove',
#  'for',
#  '2/Superhost/JP',
#  'Ctr',
#  'Quiet',
#  ',',
#  'Spacious',
#  '2BD',
#  'in',
#  'Boston',
#  "'s",
#  'JP',
#  '!',
#  'Large',
#  'Sunny',
#  'Apartment',
#  'in',
#  'JP',
#  '3',
#  'BR',
#  'Apartment',
#  'with',
#  'Kitchenette',
#  'A',
#  'quiet',
#  ',',
#  'green',
#  'oasis',
#  'in',
#  'funky',
#  'JP',
#  '!',
#  'Comfortable',
#  'Private',
#  'Bedroom',
#  'for',
#  '2',
#  'Excellent',
#  'Room',
#  '!',
#  'Right',
#  'by',
#  'the',
#  'Subway',
#  'Charming',
#  'Boston',
#  'Apartment',
#  'Cozy',
#  '1',
#  'Bd',
#  'Artist',
#  "'s",
#  'Sanctuary',
#  'Peaceful/Fun',
#  'area',
#  ',',
#  '4',
#  'minute',
#  'walk',
#  'to',
#  '``',
#  'T',
#  "''",
#  'Treetop',
#  'Room',
#  'in',
#  'Sunny',
#  'Pondside',
#  'Home',
#  'CITY',
#  'HOME',
#  'COUNTRY',
#  'FEEL',
#  ',',
#  'Boston',
#  ',',
#  'MA',
#  'USA',
#  'Lovely',
#  'home',
#  'in',
#  'Jamaica',
#  'Plain',
#  'Boston',
#  'Treetop',
#  '2+BR',
#  'Condo',
#  'w/',
#  'Guest',
#  'Hammock',
#  'Room',
#  'in',
#  'Pondside',
#  'Apt',
#  '!',
#  'One',
#  'Bedroom',
#  'Studio',
#  'Garden',
#  'Apartment',
#  'Queen',
#  'Bed/Near',
#  'Subway/Free',
#  'Passes',
#  'Super',
#  'Cozy',
#  'Apt',
#  '-',
#  'An',
#  'Artist',
#  "'s",
#  'Home',
#  'Charming',
#  'Apartment',
#  ',',
#  'Jamaica',
#  'Plain',
#  'Treetop',
#  'Jamaica',
#  'Plain',
#  'home',
#  'Private',
#  'room',
#  'in',
#  'great',
#  'JP',
#  'location',
#  '!',
#  "T'BEST",
#  ':',
#  'Priv',
#  '.',
#  'Bath',
#  ',',
#  'Deck',
#  ';',
#  'Subway',
#  ',',
#  'Parking',
#  'Option',
#  'Parkside',
#  'Apartment-',
#  'Cozy',
#  'and',
#  'Roomy',
#  '!',
#  'Centered',
#  'on',
#  'Centre',
#  'Pvt',
#  'tree',
#  'top',
#  'room',
#  'in',
#  'great',
#  'location',
#  'Family-Friendly',
#  'Victorian',
#  'Townhouse',
#  'Lovely',
#  'private',
#  '4',
#  'bedroom',
#  'apt',
#  'Light',
#  'and',
#  'airy',
#  'separate',
#  'apartment',
#  'in',
#  'funky',
#  'JP',
#  '2',
#  'bedroom',
#  'Jamaica',
#  'Plain',
#  'Egleston',
#  'Square',
#  'w/',
#  'parking',
#  'Beautiful',
#  'Apartment',
#  'in',
#  'Boston',
#  '!',
#  'Small',
#  'Cozy',
#  'Room',
#  'in',
#  'Beautiful',
#  'Place',
#  'Cozy',
#  'guest',
#  'room',
#  '.',
#  'Awesome',
#  'location',
#  '!',
#  'Family-friendly',
#  'private',
#  'room',
#  'Beautiful',
#  'Victorian',
#  'on',
#  'Quiet',
#  'Street',
#  'Full',
#  'One-Bedroom',
#  'in',
#  'Jamaica',
#  'Plain',
#  'TWO',
#  'BEDROOM',
#  'APARTMENT',
#  'Rustic',
#  'Room/Free',
#  'Transit/By',
#  'Subway',
#  'Cozy',
#  'guest',
#  'room',
#  ',',
#  'great',
#  'location',
#  '!',
#  'One',
#  'private',
#  'room',
#  'in',
#  'Jamaica',
#  'Plain',
#  'Family',
#  'friendly',
#  ',',
#  'great',
#  'location',
#  'Cozy',
#  '&',
#  'Private',
#  'Room',
#  'close',
#  'to',
#  'city',
#  'Jamaica',
#  'Plain',
#  "'s",
#  'Urban',
#  'Oasis',
#  'Gracious',
#  ...]

# %%
# set english stopwords
stopwords_eng = set(nltk.corpus.stopwords.words('english'))

# Remove single-character tokens (mostly punctuation)
words = [word for word in words if len(word) > 1]


# Remove numbers
words = [word for word in words if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words = [word.lower() for word in words]

# remove stopwords
words = [word for word in words if word not in stopwords_eng]

# %%
word_pos = nltk.pos_tag(words)
word_pos_15 = word_pos[0:16]
word_pos_15
# Out:
# [('charming', 'VBG'),
#  ('room', 'NN'),
#  ('pet', 'NN'),
#  ('friendly', 'JJ'),
#  ('apt', 'JJ'),
#  ('mexican', 'JJ'),
#  ('folk', 'NN'),
#  ('art', 'NN'),
#  ('boston', 'NN'),
#  ('spacious', 'JJ'),
#  ('sunny', 'NN'),
#  ('bedroom', 'NN'),
#  ('suite', 'NN'),
#  ('historic', 'JJ'),
#  ('home', 'NN'),
#  ('come', 'VBP')]

# %%
word_pos_df = pd.DataFrame(word_pos)
word_pos_df = word_pos_df.rename(columns={0:"words",1:"part_of_speech"})
word_pos_df
# Out:
#              words part_of_speech
# 0         charming            VBG
# 1             room             NN
# 2              pet             NN
# 3         friendly             JJ
# 4              apt             JJ
# ...            ...            ...
# 12589         near             IN
# 12590        great             JJ
# 12591     location             NN
# 12592        train             NN
# 12593  restaurants            NNS
#
# [12594 rows x 2 columns]

# %%
#prod[prod['Color'] == 'Black'].head(3)
#prod[ (prod['ListPrice'] > 50) | (prod['Size'] != 'XL') ].head(3)
#word_pos_df=word_pos_df[(word_pos_df['part_of_speech']=='JJ') | (word_pos_df['part_of_speech']=='JJS') | (word_pos_df['part_of_speech']=='JJR')|(word_pos_df['words']!='boston')]
#word_pos_df[word_pos_df['part_of_speech']=='VBG'].head(10)
word_pos_df = word_pos_df[word_pos_df['words']!='boston']
word_pos_df
# Out:
#              words part_of_speech
# 0         charming            VBG
# 1             room             NN
# 2              pet             NN
# 3         friendly             JJ
# 4              apt             JJ
# ...            ...            ...
# 12589         near             IN
# 12590        great             JJ
# 12591     location             NN
# 12592        train             NN
# 12593  restaurants            NNS
#
# [12084 rows x 2 columns]

# %%
#df = df.value_counts().rename_axis('unique_values').reset_index(name='counts')
word_count_name = (word_pos_df['words'].value_counts().rename_axis('words').reset_index(name='count'))
word_count_name.head(2)
# word_count_desc=pd.DataFrame(word_count_desc)
# word_count_desc.head(10)
# Out:
#   words  count
# 0  room    477
# 1   end    272

# %%
word_count_name.sort_values(by=['count'],ascending=False,inplace=True)
word_count_name.head()
# Out:
#        words  count
# 0       room    477
# 1        end    272
# 2    bedroom    271
# 3    private    260
# 4  apartment    225

# %%
word_count_name_10=word_count_name.head(10)
wc_desc_plot=word_count_name_10.plot.bar(x='words',y='count')
